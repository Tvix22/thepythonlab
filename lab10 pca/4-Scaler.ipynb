# %%
features.shape
# Out:
# (2169, 69)

# %%
X = features
X2 = X
X = MinMaxScaler().fit_transform(X)
X = pd.DataFrame(X,columns=X2.columns).set_index(X2.index)
X = X.dropna()

# %%
X
# Out:
#                   es    es_vol     es_oi  es_delta_vol  es_delta_vol2  \
# Date
# 2011-02-01  0.104716  0.306433  0.712614      0.357690       0.518518
# 2011-02-02  0.103386  0.191892  0.720282      0.277634       0.366966
# 2011-02-03  0.104958  0.263324  0.713429      0.470170       0.391906
# 2011-02-04  0.106892  0.223202  0.717826      0.354680       0.423383
# 2011-02-07  0.111004  0.209236  0.725301      0.381759       0.456352
# ...              ...       ...       ...           ...            ...
# 2019-12-03  0.969649  0.315916  0.687442      0.433789       0.597097
# 2019-12-04  0.979323  0.206729  0.682060      0.283177       0.504286
# 2019-12-05  0.982588  0.179103  0.680683      0.367617       0.429225
# 2019-12-06  0.996252  0.176048  0.679629      0.393056       0.456401
# 2019-12-09  0.990689  0.150453  0.671444      0.369719       0.488482
#
#             es_delta_vol3  es_range_oh  es_range_oc  es_range_ol  es_range_oo  \
# Date
# ...
